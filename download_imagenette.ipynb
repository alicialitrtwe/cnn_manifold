# %% [markdown]
# <a href="https://colab.research.google.com/github/alicialitrtwe/cnn_manifold/blob/main/collect_activation_manifold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installations
# !pip -q install lucid>=0.3.6
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# General support
import math
import tensorflow as tf
import numpy as np
import json

# General lucid code
import lucid.modelzoo.vision_models as models

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip uninstall tensorflow_datasets
# !pip --no-cache-dir install tensorflow_datasets
# Out:
# Can't uninstall 'tensorflow-datasets'. No files were found to uninstall.
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow_datasets as tfds

# %%
# Setup the data provider for imagenet
# Note you will need to download imagenet data yourself and setup a data provider
# http://image-net.org/download

# data_split = imagenet.get_split(options['split'])
# provider = tf.contrib.slim.dataset_data_provider.DatasetDataProvider(data_split, seed=7)
# image_tensor, t_label, t_record_key, t_label_text = provider.get(["image", "label", "record_key", "label_text"])

# %%
DOWNLOADIR = '/content/drive/MyDrive/cnn_embed/imagenette_data'
BASEDIR = '/content/drive/MyDrive/cnn_embed/imagenette_tf_records/'

# %%
imagenette =tfds.load('imagenette/full-size-v2:1.0.0',  data_dir=BASEDIR, download=False,
                                             download_and_prepare_kwargs= {'download_dir':DOWNLOADIR})

# %%
imagenette['train']
# Out:
# <PrefetchDataset shapes: {image: (None, None, 3), label: ()}, types: {image: tf.uint8, label: tf.int64}>

# %%
# !cp /content/drive/MyDrive/cnn_embed/datasets/tensorflow_datasets/image_classification/imagenette_labels.txt /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/image_classification/imagenette_labels.txt

# %%
data_split = imagenette.get_split(options['split'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-566f03fde293> in <module>()
# ----> 1 data_split = imagenette.get_split(options['split'])
#
# AttributeError: 'dict' object has no attribute 'get_split'

# %%
# %tensorflow_version 1.x
import tensorflow as tf
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %%
provider = tf.contrib.slim.dataset_data_provider.DatasetDataProvider(imagenette['train'], seed=7)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-91a3b2c06757> in <module>()
# ----> 1 provider = tf.contrib.slim.dataset_data_provider.DatasetDataProvider(imagenette['train'], seed=7)
#
# AttributeError: module 'tensorflow' has no attribute 'contrib'
